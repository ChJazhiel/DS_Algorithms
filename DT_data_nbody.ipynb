# %% [markdown]
# # Import utilites

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %% [markdown]
# CHECK IF STANDARDIZED VALUES HAVE AN IMPACT ON THE RESULT
#
#
# -Normalization is good to use when you know that the distribution of your data does not follow a Gaussian distribution. This can be useful in algorithms that do not assume any distribution of the data like K-Nearest Neighbors and Neural Networks.
#
# -Standardization, on the other hand, can be helpful in cases where the data follows a Gaussian distribution. However, this does not have to be necessarily true. Also, unlike normalization, standardization does not have a bounding range. So, even if you have outliers in your data, they will not be affected by standardization.
#
#
# SO far, I have not seen any difference when doing standardization on the data

# %% [markdown]
# # Load dataset

# %%
dict_data = np.load('nbody_data.npz')
test_flags  = dict_data['test_flags']
test_hosts  = dict_data['test_hosts']
test_mass   = dict_data['test_mass']
test_labels = dict_data['test_labels']
test_input  = dict_data['test_input']
#test_snid   = dict_data['test_snid']
#test_labels = dict_data['test_labels']
print(test_mass)
print(np.sum(test_labels))
# Out:
# [-1.00000000e+00 -1.00000000e+00 -1.00000000e+00 ...  3.43922706e+12
#   3.73214214e+12 -1.00000000e+00]
# 17544

# %% [markdown]
# # Visualize dataset distribution

# %%
dr1 = pd.DataFrame(test_input[0], columns = ['dr1'])
dr2 = pd.DataFrame(test_input[1], columns = ['dr2'])
dr3 = pd.DataFrame(test_input[2], columns = ['dr3'])
dr4 = pd.DataFrame(test_input[3], columns = ['dr4'])
dr5 = pd.DataFrame(test_input[4], columns = ['dr5'])
dr6 = pd.DataFrame(test_input[5], columns = ['dr6'])
dr7 = pd.DataFrame(test_input[6], columns = ['dr7'])
dr8 = pd.DataFrame(test_input[7], columns = ['dr8'])
dr9 = pd.DataFrame(test_input[8], columns = ['dr9'])
dr10 = pd.DataFrame(test_input[9], columns = ['dr10'])
lbl = pd.DataFrame(test_labels, columns =['labels'])

df = pd.concat([dr1, dr2, dr3, dr4, dr5, dr6, dr7, dr8, dr9, dr10, lbl], axis=1, ignore_index=False, sort=False)
df.describe()
# Out:
#                 dr1           dr2           dr3           dr4           dr5  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean       0.005127      0.003976      0.003287      0.002492      0.001943
# std        0.064751      0.056255      0.050816      0.043809      0.038280
# min       -0.227063     -0.194014     -0.173785     -0.159018     -0.138782
# 25%       -0.039752     -0.034953     -0.031945     -0.028010     -0.024414
# 50%        0.002010      0.001781      0.001620      0.001314      0.001093
# 75%        0.047154      0.040558      0.036602      0.031390      0.027280
# max        0.325070      0.281706      0.253833      0.205020      0.166184
#
#                 dr6           dr7           dr8           dr9          dr10  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean       0.001504      0.001148      0.000830      0.000575      0.000387
# std        0.032804      0.027640      0.023154      0.019068      0.015514
# min       -0.115022     -0.100731     -0.084828     -0.069451     -0.057891
# 25%       -0.021074     -0.017772     -0.015155     -0.012752     -0.010342
# 50%        0.000732      0.000408      0.000299      0.000212      0.000218
# 75%        0.023348      0.019663      0.016471      0.013544      0.010975
# max        0.145021      0.121187      0.097495      0.072467      0.058847
#
#             labels
# count  50000.00000
# mean       0.35088
# std        0.47725
# min        0.00000
# 25%        0.00000
# 50%        0.00000
# 75%        1.00000
# max        1.00000

# %%
import seaborn as sns
#import seaborn as sns
# %matplotlib inline
#%matplotlib qt
#matplotlib notebook

df1_0 = df[df.labels == 0]
df1_1 = df[df.labels == 1]

sns.distplot(df1_0['dr1'], kde=True, hist=False, label='label = 0')
sns.distplot(df1_1['dr1'], kde=True, hist=False, label='label = 1')
plt.axvline(0.012)
plt.legend()
sns.set(style="darkgrid")
plt.show()


sns.distplot(df1_0['dr2'], kde=True, hist=False, label='label = 0')
sns.distplot(df1_1['dr2'], kde=True, hist=False, label='label = 1')
#plt.axvline()
plt.legend()
sns.set(style="darkgrid")
plt.show()

sns.distplot(df1_0['dr3'], kde=True, hist=False, label='label = 0')
sns.distplot(df1_1['dr3'], kde=True, hist=False, label='label = 1')
#plt.axvline()
plt.legend()
sns.set(style="darkgrid")
plt.show()

sns.distplot(df1_0['dr4'], kde=True, hist=False, label='label = 0')
sns.distplot(df1_1['dr4'], kde=True, hist=False, label='label = 1')
#plt.axvline()
plt.legend()
sns.set(style="darkgrid")
plt.show()

sns.distplot(df1_0['dr5'], kde=True, hist=False, label='label = 0')
sns.distplot(df1_1['dr5'], kde=True, hist=False, label='label = 1')
#plt.axvline()
plt.legend()
sns.set(style="darkgrid")
plt.show()

sns.distplot(df1_0['dr6'], kde=True, hist=False, label='label = 0')
sns.distplot(df1_1['dr6'], kde=True, hist=False, label='label = 1')
#plt.axvline()
plt.legend()
sns.set(style="darkgrid")
plt.show()

sns.distplot(df1_0['dr7'], kde=True, hist=False, label='label = 0')
sns.distplot(df1_1['dr7'], kde=True, hist=False, label='label = 1')
#plt.axvline()
plt.legend()
sns.set(style="darkgrid")
plt.show()

sns.distplot(df1_0['dr8'], kde=True, hist=False, label='label = 0')
sns.distplot(df1_1['dr8'], kde=True, hist=False, label='label = 1')
#plt.axvline()
plt.legend()
sns.set(style="darkgrid")
plt.show()

sns.distplot(df1_0['dr9'], kde=True, hist=False, label='label = 0')
sns.distplot(df1_1['dr9'], kde=True, hist=False, label='label = 1')
#plt.axvline()
plt.legend()
sns.set(style="darkgrid")
plt.show()

sns.distplot(df1_0['dr10'], kde=True, hist=False, label='label = 0')
sns.distplot(df1_1['dr10'], kde=True, hist=False, label='label = 1')
#plt.axvline()
plt.legend()
sns.set(style="darkgrid")
plt.show()

# %% [markdown]
# # sort values by labels and randomly choose 17000 samples of each label

# %%
df_0 = df.sort_values('labels').head(32456).sample(17300)
df_1 = df.sort_values('labels').tail(17544).sample(17300) 
df_1
# Out:
#             dr1       dr2       dr3       dr4       dr5       dr6       dr7  \
# 26010  0.121827  0.084999  0.052281  0.027553  0.014256  0.009935  0.007716
# 15744 -0.031447 -0.022213 -0.014988 -0.012142 -0.025513 -0.027607 -0.024929
# 28663 -0.018983 -0.026119 -0.023248 -0.010866 -0.001780  0.004892  0.005272
# 541   -0.000472 -0.004888 -0.000988  0.005075  0.014557  0.022948  0.036358
# 26889  0.067824  0.064430  0.060909  0.056273  0.049437  0.051458  0.047199
# 22206  0.113244  0.098406  0.086784  0.071639  0.055456  0.041305  0.021871
# 26278  0.128282  0.104468  0.078858  0.063791  0.058686  0.030738  0.000390
# 46035  0.063668  0.053938  0.050439  0.057827  0.064141  0.060987  0.044318
# 29488  0.108256  0.100022  0.092616  0.093005  0.079515  0.067054  0.055041
# 23599  0.041207  0.056218  0.057117  0.060431  0.062650  0.059363  0.053516
# 11048 -0.054756 -0.049372 -0.051844 -0.039937 -0.033862 -0.032666 -0.023151
# 38993  0.140081  0.111470  0.090937  0.073969  0.054204  0.042360  0.037352
# 37263  0.006739  0.020558  0.023137  0.015628  0.011762  0.010262  0.018727
# 21434 -0.013771  0.002698  0.017442  0.045596  0.058431  0.062062  0.057147
# 16661 -0.037117 -0.030663 -0.015420  0.009887  0.013439  0.005299  0.003004
# 36657  0.093506  0.067504  0.051490  0.044783  0.034537  0.033542  0.034885
# 37456  0.015861  0.007536  0.000411       1
# 45934  0.003953  0.003200  0.002741       1
# 23274  0.023059  0.003704 -0.000028       1
# 20077  0.043151  0.033920  0.025377       1
# 12251  0.034835  0.028971  0.023305       1
# 23771  0.016675  0.024361  0.018719       1
#
# [17300 rows x 11 columns]

# %% [markdown]
# #  choose a train and test split dataset without sklearn
# I did tested this with train_test_split() function from sklear and see no further evidence of an improvement

# %% [markdown]
# Concatenate the dataset by its labels and merge, then random shuffle the samples taking into account we have a balanced class list (17000 label 0 and 17000 label 1)

# %%
df_r = pd.concat([df_0, df_1]) ###MERGE THE DATASET
shuffle_df = df_r.sample(frac = 1.0)  ### SHUFFLE THE DATASET EVENLY

train_size = int(0.8 * len(df_r)) # Define a size for your train set 


train_set = shuffle_df[:train_size] # Split your dataset 
test_set = shuffle_df[train_size:] 

#THE "Disadvantage" with this process is that our sets are not randomly selected
# in change we select the first rows as the training set, and the last rows as the test set
#but, as I stated previously, this DOES NOT affect the overall result
shuffle_df
# Out:
#             dr1       dr2       dr3       dr4       dr5       dr6       dr7  \
# 3527   0.151547  0.121172  0.093748  0.072463  0.056157  0.046484  0.042376
# 48792  0.095685  0.081795  0.075802  0.054766  0.039402  0.026024  0.011780
# 20491 -0.014789 -0.025091 -0.027351 -0.019495 -0.005036  0.008388  0.003771
# 45323  0.004469  0.010364  0.017274  0.018381  0.023452  0.033035  0.036369
# 4774   0.085004  0.118490  0.125293  0.129199  0.119194  0.096967  0.074624
# 10981  0.043166  0.027062  0.022697  0.025151  0.021977  0.009721  0.002263
# 40680 -0.014507  0.004680  0.025608  0.053395  0.064195  0.056236  0.040481
# 28047 -0.065731 -0.054807 -0.042857 -0.030270 -0.025529 -0.027788 -0.024057
# 40007  0.049617  0.046898  0.049076  0.048679  0.048842  0.048317  0.035453
# 48509 -0.144590 -0.134604 -0.123043 -0.120319 -0.111938 -0.091867 -0.069850
# 3686   0.100784  0.087691  0.085194  0.099415  0.106035  0.088537  0.060512
# 23227  0.003441  0.007441  0.011399  0.019431  0.028709  0.038009  0.031540
# 22231  0.067168  0.056824  0.052081  0.041767  0.037043  0.037711  0.033878
# 29770 -0.089870 -0.060969 -0.048816 -0.038823 -0.029133 -0.017313 -0.010886
# 1217  -0.022236 -0.003063  0.011367  0.040992  0.056839  0.053710  0.043196
# 30088  0.064704  0.074230  0.069574  0.056996  0.053532  0.048890  0.041579
# 34855  0.076626  0.041071  0.028894  0.021691  0.017894  0.002310 -0.008186
# 25277  0.014830  0.017221  0.009347 -0.001027 -0.004333 -0.002921 -0.011451
# 24863  0.050217  0.042778  0.039546  0.039647  0.034369  0.026857  0.030317
# 43092  0.114712  0.074762  0.056066  0.032013  0.021846  0.014212  0.014105
# 9255   0.060152  0.040688  0.022677  0.009570 -0.004570 -0.023655 -0.026453
# 4057  -0.014709 -0.014146 -0.021773 -0.022688 -0.018772 -0.012036 -0.001604
# 29069  0.083619  0.056616  0.022703  0.005911  0.010110  0.013820  0.010059
# 15956  0.026133  0.022091  0.021659  0.018734  0.020777  0.021776  0.014521
# 27874  0.113524  0.103241  0.093241  0.076350  0.059619  0.042382  0.044908
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels
def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = classes
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax
    


np.set_printoptions(precision=2)

# %% [markdown]
# # select the data values, X for the attributes, y for the labels

# %%
X = shuffle_df.drop(['labels'], axis = 1)
y = shuffle_df.labels
X_train = train_set.drop(['labels'], axis = 1)
X_test = test_set.drop(['labels'], axis= 1)
y_train = train_set.labels
y_test = test_set.labels

# %% [markdown]
# # Import sklearn models and metrics, for this we use Decision tree classifier and cross validation score to test accuracy metric

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.model_selection import cross_val_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score

# %% [markdown]
# # Create the Decision tree classifier for the above dataset, notice the kwargs on the DecisionTreeClassifer() function, as the max_depth and min_samples_leaf will be explained further

# %%
### Criterion=entropy: Shannon entropy for binary classification, Entropy is best because the 
### average entropy after a split is usually not the same for the parent node as it is for a child node
### the division rule continues until we get a pure node

### min samples leaf = 20: I choose this number because Rockstar uses a similar threshold to determine
### wheter the code would give you a halo or not, by default, a halo is defined by 20 particles minimum

### class weight = balanced: we know, for simple construction that our dataset is evenly distributed 
### by labels, so it is a good choice, at least from my point of view, to say that the class weights are 
### balanced

### max depth = 8: going very deep in our decision tree would lead in overfitting, this has to do with 
### the problem of misclassification and learning from noise rather than data
### I would choose 10, as 10 is the number of features we have at our disposal, and thinking that 
### each split gets rid ofo of 1 feature, this would be acceptable but I've seen from various testings
### that this leads to overfitting

dt = DecisionTreeClassifier(criterion='entropy',min_samples_leaf=20, max_depth=10, class_weight='balanced')
dt = dt.fit(X_train, y_train)

#Predict the response for test dataset
ypred = dt.predict(X_test)
#Model accuracy, how often is the classifier correct

print('Traning and Testing on non standardized values\n');

print("Accuracy:", metrics.accuracy_score(y_test, ypred))

for i, score_tree in enumerate(cross_val_score(dt, X, y, cv = 10)):
    print('Decision tree accuracy for the %d score: %0.2f' % (i, score_tree))
score_tree=cross_val_score(dt, X, y, cv=10)
#score_tree
cv_scores = []
print("Decision Tree Accuracy: %0.2f (+/- %0.2f)" % (score_tree.mean(), score_tree.std() * 2 ))
cv_score = score_tree.mean()
cv_scores.append(cv_score)

### We perform a cross validation score to see how accurate our decision tree is by 
### splitting the dataset into 10 folds for training and testing
# Out:
# Traning and Testing on non standardized values
#
# ('Accuracy:', 0.7630057803468208)
# Decision tree accuracy for the 0 score: 0.77
# Decision tree accuracy for the 1 score: 0.75
# Decision tree accuracy for the 2 score: 0.76
# Decision tree accuracy for the 3 score: 0.77
# Decision tree accuracy for the 4 score: 0.76
# Decision tree accuracy for the 5 score: 0.77
# Decision tree accuracy for the 6 score: 0.76
# Decision tree accuracy for the 7 score: 0.78
# Decision tree accuracy for the 8 score: 0.77
# Decision tree accuracy for the 9 score: 0.75
# Decision Tree Accuracy: 0.76 (+/- 0.02)

# %%
print(np.sum(y_test))
print(np.sum(ypred))
# Out:
# 3439
# 3635

# %% [markdown]
# # Confusion Matrix

# %%
class_names=['Not in Halo','in Halo']
# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(y_test, ypred, classes=class_names, normalize=True,
                      title='Confusion matrix for ENZO dataset')
plt.grid(False)
plt.show()
# Out:
# Normalized confusion matrix
# [[0.74 0.26]
#  [0.21 0.79]]

# %% [markdown]
# We see that for our model, the confusion matrix is actually pretty good, we can check if we can improve it by changing some kwargs on the decision tree function, it also would be helpful to call the plot tree function from exportgraph viz, but as a 10 depth tree, it is very large, we'll check on that later

# %% [markdown]
# # ROC CURVE
# The ROC curve is a visual representation of our classifier, it graphs the contrast of TPR and FPR of various thresholds, it is directly calculated from the decision tree and the confusion matriz, this is where number of samples in classification nodes becomes important, if we don't set a threshold in that particular case, the ROC curve is a sharp line, meaning that the classification is 100 % correct or incorrect, whereas giving a min number of samples for leaf nodes gives us the following statement "we have a particle that fell (not fell) inside a halo with this probability" ROC curves are, in a sort of speaking, a representation of that probability.
#
# The AUC of the ROC curve, however, is the important feature here, as it tells us how good our classifier is.
#
# The scores goes as the following
#
# .- AUC = 1.0 - 0.9: great classificator, even perfect
#
# .- AUC = 0.89 - 0.8: good classificator
#
# .- AUC = 0.79 - 0.7: not so bad classificator
#
# .- AUC = 0.69 - 0.6: not good classificator
#
# .- AUC = 0.59 and below: almost random or completely random classificator (your model is not learning)

# %%
from sklearn.metrics import roc_auc_score, roc_curve, auc

r_probs = [0 for _ in range(len(y_test))] ### random classification values
dt_probs = dt.predict_proba(X_test) ### predicts probabilities discussed before
dt_probs = dt_probs[:, 1] ## we choose the first column

r_auc = roc_auc_score(y_test, r_probs)
dt_auc = roc_auc_score(y_test, dt_probs)

print('Random (chance) Prediction: AUROC = %.3f' % (r_auc))
print('Decision Tree: AUROC = %.3f' % (dt_auc))

r_fpr, r_tpr, _ = roc_curve(y_test, r_probs)
dt_fpr, dt_tpr, _ = roc_curve(y_test, dt_probs)
plt.plot(r_fpr, r_tpr, linestyle='--', label='Random prediction (AUROC = %0.3f)' % r_auc)
plt.plot(dt_fpr, dt_tpr, marker='.', label='Decision Tree (AUROC = %0.3f)' % dt_auc)
plt.title('ROC Plot, all features, ENZO dataset')
# Axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# Show legend
plt.legend() # 
# Show plot
plt.show()
# Out:
# Random (chance) Prediction: AUROC = 0.500
# Decision Tree: AUROC = 0.837

# %% [markdown]
# # Learning Curve
# It shows if our model can be improved by using more data or reducing features, it is said that the model is "learning" if the accuracy score of the validation set goes up in the "y" axis, the high accuracy on the training set is due to "underfitting" but eventually comes closer to the value of the validation set

# %%
from sklearn.model_selection import learning_curve
# Create CV training and test scores for various training set sizes
train_sizes, train_scores, test_scores = learning_curve(dt, 
                                                        X, 
                                                        y,
                                                        # Number of folds in cross-validation
                                                        cv=10,
                                                        # Evaluation metric
                                                        scoring='accuracy',
                                                        # Use all computer cores
                                                        n_jobs=-1, 
                                                        # 50 different sizes of the training set
                                                        train_sizes=np.linspace(0.01, 1.0, 50))

# %%
#Create means and standard deviations for train set scores

train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)

# Create means and standard deviations of test set scores
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# Draw lines
plt.plot(train_sizes, train_mean, '--', color='r',  label="Training score")
plt.plot(train_sizes, test_mean, color='b', label="Cross-validation score")

# Draw bands
plt.fill_between(train_sizes,
                 train_mean - train_std,
                 train_mean + train_std,
                 color="r", alpha =0.15)

plt.fill_between(train_sizes,
                 test_mean - test_std,
                 test_mean + test_std,
                 color="b", alpha = 0.15)

# Create plot
plt.title("Learning Curve, All Features, ENZO dataset")
plt.xlabel("Training Set Size"), plt.ylabel("Accuracy Score"), plt.legend(loc="best")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Feature Importance
#
# How important are the features in our ds in order to make decisions and reduce entropy

# %%
features = ['dr1', 'dr2', 'dr3', 'dr4', 'dr5', 'dr6', 'dr7', 'dr8', 'dr9', 'dr10']

feature_imp = pd.Series(dt.feature_importances_,index=features)
print(feature_imp)

# Creating a bar plot
sns.barplot(x=feature_imp.index, y=feature_imp)
# Add labels to your graph
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
plt.legend()
plt.show()
# Out:
# dr1     0.021486
# dr2     0.012353
# dr3     0.035439
# dr4     0.773831
# dr5     0.016594
# dr6     0.013975
# dr7     0.047711
# dr8     0.026562
# dr9     0.033114
# dr10    0.018935
# dtype: float64
